# %%
import os
import time
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, classification_report,confusion_matrix
import warnings
from sklearn.exceptions import UndefinedMetricWarning, ConvergenceWarning, RuntimeWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=ConvergenceWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
# Loading the dataset
data1 = pd.read_csv('data/Monday-WorkingHours.pcap_ISCX.csv', encoding='utf-8')
data2 = pd.read_csv('data/Tuesday-WorkingHours.pcap_ISCX.csv', encoding='utf-8')
data3 = pd.read_csv('data/Wednesday-workingHours.pcap_ISCX.csv', encoding='utf-8')
data4 = pd.read_csv('data/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv', encoding='utf-8')
data5 = pd.read_csv('data/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv', encoding='utf-8')
data6 = pd.read_csv('data/Friday-WorkingHours-Morning.pcap_ISCX.csv', encoding='utf-8')
data7 = pd.read_csv('data/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', encoding='utf-8')
data8 = pd.read_csv('data/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', encoding='utf-8')

# %%
data_list = [data1, data2, data3, data4, data5, data6, data7, data8]

print('Data dimensions: ')
for i, data in enumerate(data_list, start = 1):
  rows, cols = data.shape
  print(f'Data{i} -> {rows} rows, {cols} columns')
# Out:
# Data dimensions:
# Data1 -> 529918 rows, 79 columns
# Data2 -> 445909 rows, 79 columns
# Data3 -> 692703 rows, 79 columns
# Data4 -> 170366 rows, 79 columns
# Data5 -> 288602 rows, 79 columns
# Data6 -> 191033 rows, 79 columns
# Data7 -> 286467 rows, 79 columns
# Data8 -> 225745 rows, 79 columns

# %%
data = pd.concat(data_list)
rows, cols = data.shape

print('New dimension:')
print(f'Number of rows: {rows}')
print(f'Number of columns: {cols}')
print(f'Total cells: {rows * cols}')
# Out:
# New dimension:
# Number of rows: 2830743
# Number of columns: 79
# Total cells: 223628697

# %%
# Deleting dataframes after concating to save memory
for d in data_list: del d

# %%
# Renaming the columns by removing leading/trailing whitespace
col_names = {col: col.strip() for col in data.columns}
data.rename(columns = col_names, inplace = True)

# %%
data.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2830743 entries, 0 to 225744
# Data columns (total 79 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Backward Packets       int64
#  4   Total Length of Fwd Packets  int64
#  5   Total Length of Bwd Packets  int64
#  6   Fwd Packet Length Max        int64
#  7   Fwd Packet Length Min        int64
#  8   Fwd Packet Length Mean       float64
#  9   Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max        int64
#  11  Bwd Packet Length Min        int64
#  12  Bwd Packet Length Mean       float64
#  13  Bwd Packet Length Std        float64
#  14  Flow Bytes/s                 float64
#  15  Flow Packets/s               float64
#  16  Flow IAT Mean                float64
#  17  Flow IAT Std                 float64
#  18  Flow IAT Max                 int64
#  19  Flow IAT Min                 int64
#  20  Fwd IAT Total                int64
#  21  Fwd IAT Mean                 float64
#  22  Fwd IAT Std                  float64
#  23  Fwd IAT Max                  int64
#  24  Fwd IAT Min                  int64
#  25  Bwd IAT Total                int64
#  26  Bwd IAT Mean                 float64
#  27  Bwd IAT Std                  float64
#  28  Bwd IAT Max                  int64
#  29  Bwd IAT Min                  int64
#  30  Fwd PSH Flags                int64
#  31  Bwd PSH Flags                int64
#  32  Fwd URG Flags                int64
#  33  Bwd URG Flags                int64
#  34  Fwd Header Length            int64
#  35  Bwd Header Length            int64
#  36  Fwd Packets/s                float64
#  37  Bwd Packets/s                float64
#  38  Min Packet Length            int64
#  39  Max Packet Length            int64
#  40  Packet Length Mean           float64
#  41  Packet Length Std            float64
#  42  Packet Length Variance       float64
#  43  FIN Flag Count               int64
#  44  SYN Flag Count               int64
#  45  RST Flag Count               int64
#  46  PSH Flag Count               int64
#  47  ACK Flag Count               int64
#  48  URG Flag Count               int64
#  49  CWE Flag Count               int64
#  50  ECE Flag Count               int64
#  51  Down/Up Ratio                int64
#  52  Average Packet Size          float64
#  53  Avg Fwd Segment Size         float64
#  54  Avg Bwd Segment Size         float64
#  55  Fwd Header Length.1          int64
#  56  Fwd Avg Bytes/Bulk           int64
#  57  Fwd Avg Packets/Bulk         int64
#  58  Fwd Avg Bulk Rate            int64
#  59  Bwd Avg Bytes/Bulk           int64
#  60  Bwd Avg Packets/Bulk         int64
#  61  Bwd Avg Bulk Rate            int64
#  62  Subflow Fwd Packets          int64
#  63  Subflow Fwd Bytes            int64
#  64  Subflow Bwd Packets          int64
#  65  Subflow Bwd Bytes            int64
#  66  Init_Win_bytes_forward       int64
#  67  Init_Win_bytes_backward      int64
#  68  act_data_pkt_fwd             int64
#  69  min_seg_size_forward         int64
#  70  Active Mean                  float64
#  71  Active Std                   float64
#  72  Active Max                   int64
#  73  Active Min                   int64
#  74  Idle Mean                    float64
#  75  Idle Std                     float64
#  76  Idle Max                     int64
#  77  Idle Min                     int64
#  78  Label                        object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 1.7+ GB

# %%
data.describe()
# Out:
# c:\Users\burakdogan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\burakdogan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.830743e+06   2.830743e+06       2.830743e+06
# mean       8.071483e+03   1.478566e+07       9.361160e+00
# std        1.828363e+04   3.365374e+07       7.496728e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   1.550000e+02       2.000000e+00
# 50%        8.000000e+01   3.131600e+04       2.000000e+00
# 75%        4.430000e+02   3.204828e+06       5.000000e+00
# max        6.553500e+04   1.200000e+08       2.197590e+05
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            2.830743e+06                 2.830743e+06
# mean             1.039377e+01                 5.493024e+02
# std              9.973883e+02                 9.993589e+03
# min              0.000000e+00                 0.000000e+00
# 25%              1.000000e+00                 1.200000e+01
# 50%              2.000000e+00                 6.200000e+01
# 75%              4.000000e+00                 1.870000e+02
# max              2.919220e+05                 1.290000e+07
#
#        Total Length of Bwd Packets  Fwd Packet Length Max  \
# count                 2.830743e+06           2.830743e+06
# mean                  1.616264e+04           2.075999e+02
# std                   2.263088e+06           7.171848e+02
# min                   0.000000e+00           0.000000e+00
# 25%                   0.000000e+00           6.000000e+00
# 50%                   1.230000e+02           3.700000e+01
# 75%                   4.820000e+02           8.100000e+01
# max                   6.554530e+08           2.482000e+04
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           2.830743e+06            2.830743e+06           2.830743e+06
# mean            1.871366e+01            5.820194e+01           6.891013e+01
# std             6.033935e+01            1.860912e+02           2.811871e+02
# min             0.000000e+00            0.000000e+00           0.000000e+00
# 25%             0.000000e+00            6.000000e+00           0.000000e+00
# 50%             2.000000e+00            3.400000e+01           0.000000e+00
# 75%             3.600000e+01            5.000000e+01           2.616295e+01
# max             2.325000e+03            5.940857e+03           7.125597e+03
#
#        ...  act_data_pkt_fwd  min_seg_size_forward   Active Mean  \
# count  ...      2.830743e+06          2.830743e+06  2.830743e+06
# mean   ...      5.418218e+00         -2.741688e+03  8.155132e+04
# std    ...      6.364257e+02          1.084989e+06  6.485999e+05
# min    ...      0.000000e+00         -5.368707e+08  0.000000e+00
# 25%    ...      0.000000e+00          2.000000e+01  0.000000e+00
# 50%    ...      1.000000e+00          2.400000e+01  0.000000e+00
# 75%    ...      2.000000e+00          3.200000e+01  0.000000e+00
# max    ...      2.135570e+05          1.380000e+02  1.100000e+08
#
#          Active Std    Active Max    Active Min     Idle Mean      Idle Std  \
# count  2.830743e+06  2.830743e+06  2.830743e+06  2.830743e+06  2.830743e+06
# mean   4.113412e+04  1.531825e+05  5.829582e+04  8.316037e+06  5.038439e+05
# std    3.933815e+05  1.025825e+06  5.770923e+05  2.363008e+07  4.602984e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    7.420000e+07  1.100000e+08  1.100000e+08  1.200000e+08  7.690000e+07
#
#            Idle Max      Idle Min
# count  2.830743e+06  2.830743e+06
# mean   8.695752e+06  7.920031e+06
# std    2.436689e+07  2.336342e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
data.head(10)
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0             49188              4                  2                       0
# 1             49188              1                  2                       0
# 2             49188              1                  2                       0
# 3             49188              1                  2                       0
# 4             49486              3                  2                       0
# 5             49486              1                  2                       0
# 6             49486              1                  2                       0
# 7             49486              1                  2                       0
# 8                88            609                  7                       4
# 9                88            879                  9                       4
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                           12                            0
# 1                           12                            0
# 2                           12                            0
# 3                           12                            0
# 4                           12                            0
# 5                           12                            0
# 6                           12                            0
# 7                           12                            0
# 8                          484                          414
# 9                          656                         3064
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                      6                      6                6.000000
# 1                      6                      6                6.000000
# 2                      6                      6                6.000000
# 3                      6                      6                6.000000
# 4                      6                      6                6.000000
# 5                      6                      6                6.000000
# 6                      6                      6                6.000000
# 7                      6                      6                6.000000
# 8                    233                      0               69.142857
# 9                    313                      0               72.888889
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0               0.000000  ...                    20          0.0         0.0
# 1               0.000000  ...                    20          0.0         0.0
# 2               0.000000  ...                    20          0.0         0.0
# 3               0.000000  ...                    20          0.0         0.0
# 4               0.000000  ...                    20          0.0         0.0
# 5               0.000000  ...                    20          0.0         0.0
# 6               0.000000  ...                    20          0.0         0.0
# 7               0.000000  ...                    20          0.0         0.0
# 8             111.967895  ...                    20          0.0         0.0
# 9             136.153814  ...                    20          0.0         0.0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# 0           0           0        0.0       0.0         0         0  BENIGN
# 1           0           0        0.0       0.0         0         0  BENIGN
# 2           0           0        0.0       0.0         0         0  BENIGN
# 3           0           0        0.0       0.0         0         0  BENIGN
# 4           0           0        0.0       0.0         0         0  BENIGN
# 5           0           0        0.0       0.0         0         0  BENIGN
# 6           0           0        0.0       0.0         0         0  BENIGN
# 7           0           0        0.0       0.0         0         0  BENIGN
# 8           0           0        0.0       0.0         0         0  BENIGN
# 9           0           0        0.0       0.0         0         0  BENIGN
#
# [10 rows x 79 columns]

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# #### 2.1. Drop Duplicate Datas

# %%
dups = data[data.duplicated()]
print(f'Number of duplicates: {len(dups)}')
# Out:
# Number of duplicates: 308381

# %%
data = data.drop_duplicates()
print(f'New dataset shape after removing duplicates: {data.shape}')
# Out:
# New dataset shape after removing duplicates: (2522362, 79)

# %% [markdown]
# #### 2.2. Drop Duplicate Columns

# %%
col_counter = Counter(data.columns)
repeated_cols = [col for col, count in col_counter.items() if count > 1]
print("Repeated columns:", repeated_cols)

# Removing duplicated columns
if repeated_cols:
    data = data.loc[:, ~data.columns.duplicated()]
# Out:
# Repeated columns: []

# %% [markdown]
# #### 2.3. Missing and Inf Value Handling

# %%
# Initial data shape
print(f"Initial data shape: {data.shape}")

# Checking missing values per column
missing_values = data.isnull().sum()
missing_values_percentage = (missing_values / len(data)) * 100

print("\nMissing values per column (count):")
print(missing_values)

print("\nMissing values per column (percentage):")
print(missing_values_percentage)

# Plotting missing values
missing_values = missing_values[missing_values > 0]  # Only columns with missing values
missing_values_percentage = missing_values_percentage[missing_values_percentage > 0]

if not missing_values.empty:
    plt.figure(figsize=(4, 4))
    missing_values.sort_values(ascending=False).plot(kind='bar', color='skyblue')
    plt.title('Missing Values per Column')
    plt.ylabel('Number of Missing Values')
    plt.xlabel('Columns')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
else:
    print("\nNo missing values found. No plot needed.")

# Replacing inf values with NaN
data = data.replace([np.inf, -np.inf], np.nan, inplace=True)

# Checking missing values again after replacing infinities
missing_values = data.isnull().sum()
missing_values_percentage = (missing_values / len(data)) * 100

# Filling missing values with median of respective columns
print("\nFilling missing values with median values...")

for column in data.columns:
    if data[column].isnull().sum() > 0:
        median_value = data[column].median()
        data[column] = data[column].fillna(median_value)

# Checking missing values after filling
missing_values_after_filling = data.isnull().sum()

print("\nMissing values after filling with median:")
print(missing_values_after_filling)

# Verifying the data shape after filling missing values
print(f"\nData shape after filling missing values: {data.shape}")
# Out:
# Initial data shape: (2522362, 79)
#
# Missing values per column (count):
# Destination Port               0
# Flow Duration                  0
# Total Fwd Packets              0
# Total Backward Packets         0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
# Idle Std                       0
# Idle Max                       0
# Idle Min                       0
# Label                          0
# Length: 79, dtype: int64
#
# Missing values per column (percentage):
# Destination Port               0.0
# Flow Duration                  0.0
# Total Fwd Packets              0.0
# Total Backward Packets         0.0
# Total Length of Fwd Packets    0.0
#                               ...
# Idle Mean                      0.0
# Idle Std                       0.0
# Idle Max                       0.0
# Idle Min                       0.0
# Label                          0.0
# Length: 79, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 35
#      32 data = data.replace([np.inf, -np.inf], np.nan, inplace=True)
#      34 # Checking missing values again after replacing infinities
# ---> 35 missing_values = data.isnull().sum()
#      36 missing_values_percentage = (missing_values / len(data)) * 100
#      38 # Filling missing values with median of respective columns
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %% [markdown]
# #### 2.4. Label Corrupted Char Handling

# %%
unique_labels = data['Label'].unique()

print("Unique Labels:")
print(unique_labels)
# Out:
# Unique Labels:
# ['BENIGN' 'FTP-Patator' 'SSH-Patator' 'DoS slowloris' 'DoS Slowhttptest'
#  'DoS Hulk' 'DoS GoldenEye' 'Heartbleed' 'Web Attack � Brute Force'
#  'Web Attack � XSS' 'Web Attack � Sql Injection' 'Infiltration' 'Bot'
#  'PortScan' 'DDoS']

# %%
data['Label'] = data['Label'].replace({
    'Web Attack � Brute Force': 'Web Attack - Brute Force',
    'Web Attack � XSS': 'Web Attack - XSS',
    'Web Attack � Sql Injection': 'Web Attack - Sql Injection'
})

# %%
unique_labels = data['Label'].unique()

print("Unique Labels after the renaming:")
print(unique_labels)
# Out:
# Unique Labels after the renaming:
# ['BENIGN' 'FTP-Patator' 'SSH-Patator' 'DoS slowloris' 'DoS Slowhttptest'
#  'DoS Hulk' 'DoS GoldenEye' 'Heartbleed' 'Web Attack - Brute Force'
#  'Web Attack - XSS' 'Web Attack - Sql Injection' 'Infiltration' 'Bot'
#  'PortScan' 'DDoS']

# %% [markdown]
# #### 2.5. Dataset Distribution Visualization

# %%
class_distribution = data['Label'].value_counts()
print("Class Distribution:")
print(class_distribution)

plt.figure(figsize=(12, 6))
sns.barplot(x=class_distribution.index, y=class_distribution.values, palette='viridis')
plt.title('Class Distribution (All Classes)')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45)
plt.show()
# Out:
# Class Distribution:
# Label
# BENIGN                        2096484
# DoS Hulk                       172849
# DDoS                           128016
# PortScan                        90819
# DoS GoldenEye                   10286
# FTP-Patator                      5933
# DoS slowloris                    5385
# DoS Slowhttptest                 5228
# SSH-Patator                      3219
# Bot                              1953
# Web Attack - Brute Force         1470
# Web Attack - XSS                  652
# Infiltration                       36
# Web Attack - Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64
# C:\Users\burakdogan\AppData\Local\Temp\ipykernel_7884\3062753500.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_distribution.index, y=class_distribution.values, palette='viridis')

# %%
# Creating a dictionary that maps each label to its attack type
attack_map = {
    'BENIGN': 'BENIGN',
    'DDoS': 'DDoS',
    'DoS Hulk': 'DoS',
    'DoS GoldenEye': 'DoS',
    'DoS slowloris': 'DoS',
    'DoS Slowhttptest': 'DoS',
    'PortScan': 'Port Scan',
    'FTP-Patator': 'Brute Force',
    'SSH-Patator': 'Brute Force',
    'Bot': 'Bot',
    'Web Attack - Brute Force': 'Web Attack',
    'Web Attack - XSS': 'Web Attack',
    'Web Attack - Sql Injection': 'Web Attack',
    'Infiltration': 'Infiltration',
    'Heartbleed': 'Heartbleed'
}

# Mapping each label to its attack type
data['AttackType'] = data['Label'].map(attack_map)

# Checking the distribution of attack types
attack_type_distribution = data['AttackType'].value_counts()
print("Attack Type Distribution:")
print(attack_type_distribution)

# Plotting the distribution of attack types
plt.figure(figsize=(10, 6))
sns.barplot(x=attack_type_distribution.index, y=attack_type_distribution.values, hue=attack_type_distribution.index, palette='autumn')
plt.title('Attack Type Distribution')
plt.xlabel('Attack Type')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45)
plt.show()
# Out:
# Attack Type Distribution:
# AttackType
# BENIGN          2096484
# DoS              193748
# DDoS             128016
# Port Scan         90819
# Brute Force        9152
# Web Attack         2143
# Bot                1953
# Infiltration         36
# Heartbleed           11
# Name: count, dtype: int64

# %%
binary_labels = data['Label'].apply(lambda x: 'BENIGN' if x == 'BENIGN' else 'ATTACK')

binary_class_distribution = binary_labels.value_counts()
print("Binary Class Distribution:")
print(binary_class_distribution)

plt.figure(figsize=(8, 4))
sns.barplot(
    x=binary_class_distribution.index,
    y=binary_class_distribution.values,
    hue=binary_class_distribution.index,
    dodge=False
)
plt.legend([], [], frameon=False) 
plt.title('Binary Class Distribution (BENIGN vs ATTACK)')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.show()
# Out:
# Binary Class Distribution:
# Label
# BENIGN    2096484
# ATTACK     425878
# Name: count, dtype: int64

# %% [markdown]
# #### 2.6. Correlation Matrix

# %%
# Selecting numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Plotting correlation matrix
plt.figure(figsize=(20, 15))
sns.heatmap(numeric_data.corr(), cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### 2.7. Feature Selection Based On Correlation

# %%
# Calculate the correlation matrix
corr_matrix = numeric_data.corr()

# Select columns with correlation higher than 0.6 (absolute value)
high_corr_var = np.where(np.abs(corr_matrix) > 0.6)

# Get the pairs of features that have high correlation
high_corr_pairs = []
for i in range(len(high_corr_var[0])):
    if high_corr_var[0][i] != high_corr_var[1][i]:
        high_corr_pairs.append((numeric_data.columns[high_corr_var[0][i]], numeric_data.columns[high_corr_var[1][i]]))

# Display the highly correlated pairs
print("Highly correlated feature pairs:")
for pair in high_corr_pairs:
    print(pair)

# Drop one of each pair with high correlation (keeping the first column in each pair)
to_drop = set()
for pair in high_corr_pairs:
    to_drop.add(pair[1])  # Drop the second feature in each pair

# Removing highly correlated features from the dataset
numeric_data_reduced = numeric_data.drop(columns=to_drop)

# Displaying the shape after reduction
print(f"\nShape after feature selection: {numeric_data_reduced.shape}")
# Out:
# Highly correlated feature pairs:
# ('Flow Duration', 'Flow IAT Std')
# ('Flow Duration', 'Flow IAT Max')
# ('Flow Duration', 'Fwd IAT Total')
# ('Flow Duration', 'Fwd IAT Std')
# ('Flow Duration', 'Fwd IAT Max')
# ('Flow Duration', 'Bwd IAT Total')
# ('Flow Duration', 'Idle Mean')
# ('Flow Duration', 'Idle Max')
# ('Flow Duration', 'Idle Min')
# ('Total Fwd Packets', 'Total Backward Packets')
# ('Total Fwd Packets', 'Total Length of Bwd Packets')
# ('Total Fwd Packets', 'Subflow Fwd Packets')
# ('Total Fwd Packets', 'Subflow Bwd Packets')
# ('Total Fwd Packets', 'Subflow Bwd Bytes')
# ('Total Fwd Packets', 'act_data_pkt_fwd')
# ('Total Backward Packets', 'Total Fwd Packets')
# ('Total Backward Packets', 'Total Length of Bwd Packets')
# ('Total Backward Packets', 'Subflow Fwd Packets')
# ('Total Backward Packets', 'Subflow Bwd Packets')
# ('Total Backward Packets', 'Subflow Bwd Bytes')
# ('Total Backward Packets', 'act_data_pkt_fwd')
# ('Total Length of Fwd Packets', 'Subflow Fwd Bytes')
# ('Total Length of Bwd Packets', 'Total Fwd Packets')
# ('Total Length of Bwd Packets', 'Total Backward Packets')
# ('Total Length of Bwd Packets', 'Subflow Fwd Packets')
# ('Total Length of Bwd Packets', 'Subflow Bwd Packets')
# ('Total Length of Bwd Packets', 'Subflow Bwd Bytes')
# ('Total Length of Bwd Packets', 'act_data_pkt_fwd')
# ('Fwd Packet Length Max', 'Fwd Packet Length Mean')
# ('Fwd Packet Length Max', 'Fwd Packet Length Std')
# ('Fwd Packet Length Max', 'Avg Fwd Segment Size')
# ('Fwd Packet Length Mean', 'Fwd Packet Length Max')
# ('Fwd Packet Length Mean', 'Fwd Packet Length Std')
# ('Fwd Packet Length Mean', 'Avg Fwd Segment Size')
# ('Fwd Packet Length Std', 'Fwd Packet Length Max')
# ('Fwd Packet Length Std', 'Fwd Packet Length Mean')
# ('Fwd Packet Length Std', 'Avg Fwd Segment Size')
# ('Bwd Packet Length Max', 'Bwd Packet Length Mean')
# ('Bwd Packet Length Max', 'Bwd Packet Length Std')
# ('Bwd Packet Length Max', 'Max Packet Length')
# ('Bwd Packet Length Max', 'Packet Length Mean')
# ('Bwd Packet Length Max', 'Packet Length Std')
# ('Bwd Packet Length Max', 'Packet Length Variance')
# ('Bwd Packet Length Max', 'Average Packet Size')
# ('Bwd Packet Length Max', 'Avg Bwd Segment Size')
# ('Bwd Packet Length Min', 'Min Packet Length')
# ('Bwd Packet Length Mean', 'Bwd Packet Length Max')
# ('Bwd Packet Length Mean', 'Bwd Packet Length Std')
# ('Bwd Packet Length Mean', 'Max Packet Length')
# ('Bwd Packet Length Mean', 'Packet Length Mean')
# ('Bwd Packet Length Mean', 'Packet Length Std')
# ('Bwd Packet Length Mean', 'Packet Length Variance')
# ('Bwd Packet Length Mean', 'Average Packet Size')
# ('Bwd Packet Length Mean', 'Avg Bwd Segment Size')
# ('Bwd Packet Length Std', 'Bwd Packet Length Max')
# ('Bwd Packet Length Std', 'Bwd Packet Length Mean')
# ('Bwd Packet Length Std', 'Max Packet Length')
# ('Bwd Packet Length Std', 'Packet Length Mean')
# ('Bwd Packet Length Std', 'Packet Length Std')
# ('Bwd Packet Length Std', 'Packet Length Variance')
# ('Bwd Packet Length Std', 'Average Packet Size')
# ('Bwd Packet Length Std', 'Avg Bwd Segment Size')
# ('Flow Packets/s', 'Fwd Packets/s')
# ('Flow IAT Mean', 'Flow IAT Std')
# ('Flow IAT Mean', 'Flow IAT Max')
# ('Flow IAT Mean', 'Flow IAT Min')
# ('Flow IAT Mean', 'Fwd IAT Mean')
# ('Flow IAT Mean', 'Fwd IAT Max')
# ('Flow IAT Mean', 'Fwd IAT Min')
# ('Flow IAT Mean', 'Bwd IAT Mean')
# ('Flow IAT Mean', 'Idle Mean')
# ('Flow IAT Mean', 'Idle Max')
# ('Flow IAT Std', 'Flow Duration')
# ('Flow IAT Std', 'Flow IAT Mean')
# ('Flow IAT Std', 'Flow IAT Max')
# ('Flow IAT Std', 'Fwd IAT Total')
# ('Flow IAT Std', 'Fwd IAT Mean')
# ('Flow IAT Std', 'Fwd IAT Std')
# ('Flow IAT Std', 'Fwd IAT Max')
# ('Flow IAT Std', 'Bwd IAT Mean')
# ('Flow IAT Std', 'Bwd IAT Max')
# ('Flow IAT Std', 'Idle Mean')
# ('Flow IAT Std', 'Idle Max')
# ('Flow IAT Std', 'Idle Min')
# ('Flow IAT Max', 'Flow Duration')
# ('Flow IAT Max', 'Flow IAT Mean')
# ('Flow IAT Max', 'Flow IAT Std')
# ('Flow IAT Max', 'Fwd IAT Total')
# ('Flow IAT Max', 'Fwd IAT Mean')
# ('Flow IAT Max', 'Fwd IAT Std')
# ('Flow IAT Max', 'Fwd IAT Max')
# ('Flow IAT Max', 'Bwd IAT Max')
# ('Flow IAT Max', 'Idle Mean')
# ('Flow IAT Max', 'Idle Max')
# ('Flow IAT Max', 'Idle Min')
# ('Flow IAT Min', 'Flow IAT Mean')
# ('Fwd IAT Total', 'Flow Duration')
# ('Fwd IAT Total', 'Flow IAT Std')
# ('Fwd IAT Total', 'Flow IAT Max')
# ('Fwd IAT Total', 'Fwd IAT Std')
# ('Fwd IAT Total', 'Fwd IAT Max')
# ('Fwd IAT Total', 'Bwd IAT Total')
# ('Fwd IAT Total', 'Idle Mean')
# ('Fwd IAT Total', 'Idle Max')
# ('Fwd IAT Total', 'Idle Min')
# ('Fwd IAT Mean', 'Flow IAT Mean')
# ('Fwd IAT Mean', 'Flow IAT Std')
# ('Fwd IAT Mean', 'Flow IAT Max')
# ('Fwd IAT Mean', 'Fwd IAT Max')
# ('Fwd IAT Mean', 'Fwd IAT Min')
# ('Fwd IAT Mean', 'Bwd IAT Mean')
# ('Fwd IAT Mean', 'Bwd IAT Max')
# ('Fwd IAT Mean', 'Bwd IAT Min')
# ('Fwd IAT Mean', 'Idle Mean')
# ('Fwd IAT Mean', 'Idle Max')
# ('Fwd IAT Mean', 'Idle Min')
# ('Fwd IAT Std', 'Flow Duration')
# ('Fwd IAT Std', 'Flow IAT Std')
# ('Fwd IAT Std', 'Flow IAT Max')
# ('Fwd IAT Std', 'Fwd IAT Total')
# ('Fwd IAT Std', 'Fwd IAT Max')
# ('Fwd IAT Std', 'Bwd IAT Std')
# ('Fwd IAT Std', 'Max Packet Length')
# ('Fwd IAT Std', 'Idle Mean')
# ('Fwd IAT Std', 'Idle Max')
# ('Fwd IAT Std', 'Idle Min')
# ('Fwd IAT Max', 'Flow Duration')
# ('Fwd IAT Max', 'Flow IAT Mean')
# ('Fwd IAT Max', 'Flow IAT Std')
# ('Fwd IAT Max', 'Flow IAT Max')
# ('Fwd IAT Max', 'Fwd IAT Total')
# ('Fwd IAT Max', 'Fwd IAT Mean')
# ('Fwd IAT Max', 'Fwd IAT Std')
# ('Fwd IAT Max', 'Bwd IAT Max')
# ('Fwd IAT Max', 'Idle Mean')
# ('Fwd IAT Max', 'Idle Max')
# ('Fwd IAT Max', 'Idle Min')
# ('Fwd IAT Min', 'Flow IAT Mean')
# ('Fwd IAT Min', 'Fwd IAT Mean')
# ('Fwd IAT Min', 'Bwd IAT Mean')
# ('Fwd IAT Min', 'Bwd IAT Min')
# ('Bwd IAT Total', 'Flow Duration')
# ('Bwd IAT Total', 'Fwd IAT Total')
# ('Bwd IAT Total', 'Bwd IAT Std')
# ('Bwd IAT Total', 'Bwd IAT Max')
# ('Bwd IAT Mean', 'Flow IAT Mean')
# ('Bwd IAT Mean', 'Flow IAT Std')
# ('Bwd IAT Mean', 'Fwd IAT Mean')
# ('Bwd IAT Mean', 'Fwd IAT Min')
# ('Bwd IAT Mean', 'Bwd IAT Max')
# ('Bwd IAT Mean', 'Bwd IAT Min')
# ('Bwd IAT Std', 'Fwd IAT Std')
# ('Bwd IAT Std', 'Bwd IAT Total')
# ('Bwd IAT Std', 'Bwd IAT Max')
# ('Bwd IAT Max', 'Flow IAT Std')
# ('Bwd IAT Max', 'Flow IAT Max')
# ('Bwd IAT Max', 'Fwd IAT Mean')
# ('Bwd IAT Max', 'Fwd IAT Max')
# ('Bwd IAT Max', 'Bwd IAT Total')
# ('Bwd IAT Max', 'Bwd IAT Mean')
# ('Bwd IAT Max', 'Bwd IAT Std')
# ('Bwd IAT Max', 'Idle Mean')
# ('Bwd IAT Max', 'Idle Max')
# ('Bwd IAT Max', 'Idle Min')
# ('Bwd IAT Min', 'Fwd IAT Mean')
# ('Bwd IAT Min', 'Fwd IAT Min')
# ('Bwd IAT Min', 'Bwd IAT Mean')
# ('Fwd PSH Flags', 'SYN Flag Count')
# ('Fwd URG Flags', 'CWE Flag Count')
# ('Fwd Header Length', 'Fwd Header Length.1')
# ('Bwd Header Length', 'min_seg_size_forward')
# ('Fwd Packets/s', 'Flow Packets/s')
# ('Min Packet Length', 'Bwd Packet Length Min')
# ('Max Packet Length', 'Bwd Packet Length Max')
# ('Max Packet Length', 'Bwd Packet Length Mean')
# ('Max Packet Length', 'Bwd Packet Length Std')
# ('Max Packet Length', 'Fwd IAT Std')
# ('Max Packet Length', 'Packet Length Mean')
# ('Max Packet Length', 'Packet Length Std')
# ('Max Packet Length', 'Packet Length Variance')
# ('Max Packet Length', 'Average Packet Size')
# ('Max Packet Length', 'Avg Bwd Segment Size')
# ('Packet Length Mean', 'Bwd Packet Length Max')
# ('Packet Length Mean', 'Bwd Packet Length Mean')
# ('Packet Length Mean', 'Bwd Packet Length Std')
# ('Packet Length Mean', 'Max Packet Length')
# ('Packet Length Mean', 'Packet Length Std')
# ('Packet Length Mean', 'Packet Length Variance')
# ('Packet Length Mean', 'Average Packet Size')
# ('Packet Length Mean', 'Avg Bwd Segment Size')
# ('Packet Length Std', 'Bwd Packet Length Max')
# ('Packet Length Std', 'Bwd Packet Length Mean')
# ('Packet Length Std', 'Bwd Packet Length Std')
# ('Packet Length Std', 'Max Packet Length')
# ('Packet Length Std', 'Packet Length Mean')
# ('Packet Length Std', 'Packet Length Variance')
# ('Packet Length Std', 'Average Packet Size')
# ('Packet Length Std', 'Avg Bwd Segment Size')
# ('Packet Length Variance', 'Bwd Packet Length Max')
# ('Packet Length Variance', 'Bwd Packet Length Mean')
# ('Packet Length Variance', 'Bwd Packet Length Std')
# ('Packet Length Variance', 'Max Packet Length')
# ('Packet Length Variance', 'Packet Length Mean')
# ('Packet Length Variance', 'Packet Length Std')
# ('Packet Length Variance', 'Average Packet Size')
# ('Packet Length Variance', 'Avg Bwd Segment Size')
# ('SYN Flag Count', 'Fwd PSH Flags')
# ('RST Flag Count', 'ECE Flag Count')
# ('CWE Flag Count', 'Fwd URG Flags')
# ('ECE Flag Count', 'RST Flag Count')
# ('Average Packet Size', 'Bwd Packet Length Max')
# ('Average Packet Size', 'Bwd Packet Length Mean')
# ('Average Packet Size', 'Bwd Packet Length Std')
# ('Average Packet Size', 'Max Packet Length')
# ('Average Packet Size', 'Packet Length Mean')
# ('Average Packet Size', 'Packet Length Std')
# ('Average Packet Size', 'Packet Length Variance')
# ('Average Packet Size', 'Avg Bwd Segment Size')
# ('Avg Fwd Segment Size', 'Fwd Packet Length Max')
# ('Avg Fwd Segment Size', 'Fwd Packet Length Mean')
# ('Avg Fwd Segment Size', 'Fwd Packet Length Std')
# ('Avg Bwd Segment Size', 'Bwd Packet Length Max')
# ('Avg Bwd Segment Size', 'Bwd Packet Length Mean')
# ('Avg Bwd Segment Size', 'Bwd Packet Length Std')
# ('Avg Bwd Segment Size', 'Max Packet Length')
# ('Avg Bwd Segment Size', 'Packet Length Mean')
# ('Avg Bwd Segment Size', 'Packet Length Std')
# ('Avg Bwd Segment Size', 'Packet Length Variance')
# ('Avg Bwd Segment Size', 'Average Packet Size')
# ('Fwd Header Length.1', 'Fwd Header Length')
# ('Subflow Fwd Packets', 'Total Fwd Packets')
# ('Subflow Fwd Packets', 'Total Backward Packets')
# ('Subflow Fwd Packets', 'Total Length of Bwd Packets')
# ('Subflow Fwd Packets', 'Subflow Bwd Packets')
# ('Subflow Fwd Packets', 'Subflow Bwd Bytes')
# ('Subflow Fwd Packets', 'act_data_pkt_fwd')
# ('Subflow Fwd Bytes', 'Total Length of Fwd Packets')
# ('Subflow Bwd Packets', 'Total Fwd Packets')
# ('Subflow Bwd Packets', 'Total Backward Packets')
# ('Subflow Bwd Packets', 'Total Length of Bwd Packets')
# ('Subflow Bwd Packets', 'Subflow Fwd Packets')
# ('Subflow Bwd Packets', 'Subflow Bwd Bytes')
# ('Subflow Bwd Packets', 'act_data_pkt_fwd')
# ('Subflow Bwd Bytes', 'Total Fwd Packets')
# ('Subflow Bwd Bytes', 'Total Backward Packets')
# ('Subflow Bwd Bytes', 'Total Length of Bwd Packets')
# ('Subflow Bwd Bytes', 'Subflow Fwd Packets')
# ('Subflow Bwd Bytes', 'Subflow Bwd Packets')
# ('Subflow Bwd Bytes', 'act_data_pkt_fwd')
# ('act_data_pkt_fwd', 'Total Fwd Packets')
# ('act_data_pkt_fwd', 'Total Backward Packets')
# ('act_data_pkt_fwd', 'Total Length of Bwd Packets')
# ('act_data_pkt_fwd', 'Subflow Fwd Packets')
# ('act_data_pkt_fwd', 'Subflow Bwd Packets')
# ('act_data_pkt_fwd', 'Subflow Bwd Bytes')
# ('min_seg_size_forward', 'Bwd Header Length')
# ('Active Mean', 'Active Max')
# ('Active Mean', 'Active Min')
# ('Active Std', 'Active Max')
# ('Active Max', 'Active Mean')
# ('Active Max', 'Active Std')
# ('Active Min', 'Active Mean')
# ('Idle Mean', 'Flow Duration')
# ('Idle Mean', 'Flow IAT Mean')
# ('Idle Mean', 'Flow IAT Std')
# ('Idle Mean', 'Flow IAT Max')
# ('Idle Mean', 'Fwd IAT Total')
# ('Idle Mean', 'Fwd IAT Mean')
# ('Idle Mean', 'Fwd IAT Std')
# ('Idle Mean', 'Fwd IAT Max')
# ('Idle Mean', 'Bwd IAT Max')
# ('Idle Mean', 'Idle Max')
# ('Idle Mean', 'Idle Min')
# ('Idle Max', 'Flow Duration')
# ('Idle Max', 'Flow IAT Mean')
# ('Idle Max', 'Flow IAT Std')
# ('Idle Max', 'Flow IAT Max')
# ('Idle Max', 'Fwd IAT Total')
# ('Idle Max', 'Fwd IAT Mean')
# ('Idle Max', 'Fwd IAT Std')
# ('Idle Max', 'Fwd IAT Max')
# ('Idle Max', 'Bwd IAT Max')
# ('Idle Max', 'Idle Mean')
# ('Idle Max', 'Idle Min')
# ('Idle Min', 'Flow Duration')
# ('Idle Min', 'Flow IAT Std')
# ('Idle Min', 'Flow IAT Max')
# ('Idle Min', 'Fwd IAT Total')
# ('Idle Min', 'Fwd IAT Mean')
# ('Idle Min', 'Fwd IAT Std')
# ('Idle Min', 'Fwd IAT Max')
# ('Idle Min', 'Bwd IAT Max')
# ('Idle Min', 'Idle Mean')
# ('Idle Min', 'Idle Max')
#
# Shape after feature selection: (2522362, 20)

# %%
remaining_columns = numeric_data_reduced.columns
print("Remaining columns after removing highly correlated features:")
print(remaining_columns)
print(remaining_columns.shape)
# Out:
# Remaining columns after removing highly correlated features:
# Index(['Destination Port', 'Fwd Packet Length Min', 'Flow Bytes/s',
#        'Bwd PSH Flags', 'Bwd URG Flags', 'Bwd Packets/s', 'FIN Flag Count',
#        'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'Down/Up Ratio',
#        'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate',
#        'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'Idle Std'],
#       dtype='object')
# (20,)

# %%
numeric_data_reduced.head(10)
# Out:
#     Destination Port  Fwd Packet Length Min  Flow Bytes/s  Bwd PSH Flags  \
# 0              49188                      6  3.000000e+06              0
# 1              49188                      6  1.200000e+07              0
# 4              49486                      6  4.000000e+06              0
# 5              49486                      6  1.200000e+07              0
# 8                 88                      0  1.474548e+06              0
# 9                 88                      0  4.232082e+06              0
# 10                88                      0  5.329310e+06              0
# 11                88                      0  1.074809e+07              0
# 12              1034                      6  2.000000e+06              0
# 13                88                      0  5.558534e+06              0
#
#     Bwd URG Flags  Bwd Packets/s  FIN Flag Count  PSH Flag Count  \
# 0               0       0.000000               0               0
# 1               0       0.000000               0               0
# 4               0       0.000000               0               0
# 5               0       0.000000               0               0
# 8               0    6568.144499               0               1
# 9               0    4550.625711               0               1
# 10              0    5172.413793               0               1
# 11              0    7633.587786               0               1
# 12              0  166666.666667               0               0
# 13              0    5361.930295               0               1
#
#     ACK Flag Count  URG Flag Count  Down/Up Ratio  Fwd Avg Bytes/Bulk  \
# 0                1               1              0                   0
# 1                1               1              0                   0
# 4                1               1              0                   0
# 5                1               1              0                   0
# 8                0               0              0                   0
# 9                0               0              0                   0
# 10               0               0              0                   0
# 11               0               0              0                   0
# 12               1               0              1                   0
# 13               0               0              0                   0
#
#     Fwd Avg Packets/Bulk  Fwd Avg Bulk Rate  Bwd Avg Bytes/Bulk  \
# 0                      0                  0                   0
# 1                      0                  0                   0
# 4                      0                  0                   0
# 5                      0                  0                   0
# 8                      0                  0                   0
# 9                      0                  0                   0
# 10                     0                  0                   0
# 11                     0                  0                   0
# 12                     0                  0                   0
# 13                     0                  0                   0
#
#     Bwd Avg Packets/Bulk  Bwd Avg Bulk Rate  Init_Win_bytes_forward  \
# 0                      0                  0                     329
# 1                      0                  0                     329
# 4                      0                  0                     245
# 5                      0                  0                     245
# 8                      0                  0                    8192
# 9                      0                  0                    8192
# 10                     0                  0                    8192
# 11                     0                  0                    8192
# 12                     0                  0                    2053
# 13                     0                  0                    8192
#
#     Init_Win_bytes_backward  Idle Std
# 0                        -1       0.0
# 1                        -1       0.0
# 4                        -1       0.0
# 5                        -1       0.0
# 8                      2053       0.0
# 9                      2053       0.0
# 10                     2053       0.0
# 11                     2053       0.0
# 12                      251       0.0
# 13                     2053       0.0

# %% [markdown]
# ## 3. Binary Classification (Attack & Benign)

# %% [markdown]
# #### 3.1. Data Preparing and Sampling

# %%
# Separate features and labels
X = numeric_data_reduced.reset_index(drop=True)  # Numerical features
y = data['Label'].reset_index(drop=True)  # Labels

# Map labels: 'BENIGN' -> 0, attacks -> 1
y_binary = y.apply(lambda x: 0 if x == 'BENIGN' else 1)

# Create masks for attack and benign classes
attack_mask = (y_binary == 1)
benign_mask = (y_binary == 0)

# Apply RandomUnderSampler only on attack classes with custom sampling strategy
rus = RandomUnderSampler(sampling_strategy=lambda y: {label: min(1200, sum(y == label)) for label in np.unique(y)}, random_state=42)

# Apply undersampling only on attack data
X_attack = X[attack_mask]
y_attack = y[attack_mask]
X_attack_resampled, y_attack_resampled = rus.fit_resample(X_attack, y_attack)

# For benign, sample 12000 instances randomly
X_benign = X[benign_mask].sample(n=12000, random_state=42)
y_benign = y[benign_mask].loc[X_benign.index]

# Combine attack and benign data into a balanced dataset
X_balanced = pd.concat([X_benign, X_attack_resampled], axis=0).reset_index(drop=True)
y_balanced = pd.concat([y_benign, y_attack_resampled], axis=0).reset_index(drop=True)

# Re-map labels: 'BENIGN' -> 0, attacks -> 1
y_balanced = y_balanced.apply(lambda x: 0 if x == 'BENIGN' else 1)

# %% [markdown]
# #### 3.2. Train Test Split

# %%
# Split into train and test sets first
X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced,
    test_size=0.2, random_state=42, stratify=y_balanced
)

# %% [markdown]
# #### 3.3. Scaling

# %%
scaler = StandardScaler()

# Fit the scaler on the training data and transform both the training and test data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #### 3.4. Visaulization

# %%
# Print summary after scaling
print(f"\nTrain set shape: {X_train_scaled.shape}, Test set shape: {X_test_scaled.shape}")
print("\nTrain set class distribution:")
print(pd.Series(y_train).value_counts())

print("\nTest set class distribution:")
print(pd.Series(y_test).value_counts())
# Out:
# Train set shape: (19776, 20), Test set shape: (4944, 20)
#
# Train set class distribution:
# Label
# 1    10176
# 0     9600
# Name: count, dtype: int64
#
# Test set class distribution:
# Label
# 1    2544
# 0    2400
# Name: count, dtype: int64

# %% [markdown]
# #### 3.4. Define Models

# %%
# Define models
models = [
    ('Random Forest', RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)),
    ('SVM', SVC(C=0.5, random_state=42)),
    ('Logistic Regression', LogisticRegression(C=0.5, random_state=42, max_iter=10000)),
    ('KNN', KNeighborsClassifier(n_neighbors=5, algorithm='auto')),
    ('Decision Tree', DecisionTreeClassifier(random_state=42, max_depth=10, min_samples_split=5))
]

# %% [markdown]
# #### 3.5. Model Evaluation

# %%
from sklearn.metrics import classification_report

def evaluate_models(models, X_train, y_train, cv_splits=5, save_dir='model_logs'):
    results = {}
    os.makedirs(save_dir, exist_ok=True)

    best_model_name = None
    best_model_score = 0
    best_model_instance = None

    for name, model in models:
        print(f"Evaluating {name}...")

        start_time = time.time()

        # Cross-validation for different metrics
        accuracy = cross_val_score(model, X_train, y_train, cv=cv_splits, scoring='accuracy').mean()
        f1 = cross_val_score(model, X_train, y_train, cv=cv_splits, scoring='f1_weighted').mean()
        precision = cross_val_score(model, X_train, y_train, cv=cv_splits, scoring='precision_weighted').mean()
        recall = cross_val_score(model, X_train, y_train, cv=cv_splits, scoring='recall_weighted').mean()

        end_time = time.time()
        elapsed_time = end_time - start_time

        results[name] = {
            'accuracy': accuracy,
            'f1': f1,
            'precision': precision,
            'recall': recall,
            'cross_val_time_sec': elapsed_time
        }

        if f1 > best_model_score:
            best_model_score = f1
            best_model_name = name
            best_model_instance = model

    # Convert results to DataFrame
    results_df = pd.DataFrame(results).T
    print("\nModel Comparison (Cross-Validation Results):")
    print(results_df)

    # Save results to CSV
    log_path = os.path.join(save_dir, 'model_results_log.csv')
    results_df.to_csv(log_path, index=True)
    print(f"\nResults saved to {log_path}")

    # Plotting Scores (excluding time)
    score_metrics = ['accuracy', 'f1', 'precision', 'recall']
    results_df[score_metrics].plot(kind='barh', figsize=(10, 6), cmap='viridis')
    plt.title("Model Evaluation Scores Comparison")
    plt.xlabel("Scores")
    plt.ylabel("Models")
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.show()

    # Plotting Cross-validation Time separately
    results_df['cross_val_time_sec'].plot(kind='barh', figsize=(8, 5), color='salmon')
    plt.title("Model Cross-Validation Time Comparison")
    plt.xlabel("Time (seconds)")
    plt.ylabel("Models")
    plt.tight_layout()
    plt.show()

    # ROC AUC for the best model
    if best_model_instance is not None:
        best_model_instance.fit(X_train, y_train)

        if hasattr(best_model_instance, "predict_proba"):
            y_probs = best_model_instance.predict_proba(X_train)[:, 1]

            fpr, tpr, _ = roc_curve(y_train, y_probs)
            roc_auc = auc(fpr, tpr)

            plt.figure(figsize=(8, 6))
            plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
            plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
            plt.title(f'ROC Curve for {best_model_name}')
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.legend(loc='lower right')
            plt.tight_layout()
            plt.show()

        # Classification report for the best model on the train set
        y_train_pred = best_model_instance.predict(X_train)
        class_report = classification_report(y_train, y_train_pred)
        print(f"\nClassification Report for Best Model on Train Set:\n{class_report}")

        model_path = os.path.join(save_dir, f'best_model_{best_model_name.replace(" ", "_")}.pkl')
        joblib.dump(best_model_instance, model_path)
        print(f"Best model '{best_model_name}' saved to {model_path}")

# Call the function
evaluate_models(models, X_train, y_train)
# Out:
# Evaluating Random Forest...
# Evaluating SVM...
# Evaluating Logistic Regression...
# c:\Users\burakdogan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\burakdogan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\burakdogan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\burakdogan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Evaluating KNN...
# Evaluating Decision Tree...
#
# Model Comparison (Cross-Validation Results):
#                      accuracy        f1  precision    recall  \
# Random Forest        0.983313  0.983303   0.983656  0.983313
# SVM                  0.578024  0.484219   0.728547  0.578024
# Logistic Regression  0.755311  0.753087   0.763944  0.755311
# KNN                  0.947816  0.947791   0.948032  0.947816
# Decision Tree        0.979874  0.979864   0.980148  0.979874
#
#                      cross_val_time_sec
# Random Forest                 11.790026
# SVM                          160.003839
# Logistic Regression           25.345155
# KNN                            2.775050
# Decision Tree                  0.646571
#
# Results saved to model_logs\model_results_log.csv
# Classification Report for Best Model on Train Set:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      9600
#            1       0.97      1.00      0.99     10176
#
#     accuracy                           0.98     19776
#    macro avg       0.99      0.98      0.98     19776
# weighted avg       0.99      0.98      0.98     19776
#
# Best model 'Random Forest' saved to model_logs\best_model_Random_Forest.pkl

# %% [markdown]
# ## 4. Multi-class Attack Classification

# %% [markdown]
# #### 4.1.Prepare the Data and Split Features and Labels

# %%
# Create a copy of the dataset with 'Label' as the target column
X_all = numeric_data_reduced.copy()
X_all['Label'] = data['Label'].values  

# Filter out the 'BENIGN' class and reset the index
attack_data = X_all[X_all['Label'] != 'BENIGN'].reset_index(drop=True)

# Remove the specified attack types directly from attack_data
attack_data = attack_data[~attack_data['Label'].isin(['Infiltration', 'Web Attack - Sql Injection', 'Heartbleed'])]

# Split the data into features (X) and labels (y)
X_attack = attack_data.drop(columns=['Label'])
y_attack = attack_data['Label']

# Check the shapes and distribution of attack types
print(f"X_attack shape: {X_attack.shape}")
print(f"y_attack shape: {y_attack.shape}")
print("\nFiltered Attack type distribution:")
print(y_attack.value_counts())
# Out:
# X_attack shape: (425810, 20)
# y_attack shape: (425810,)
#
# Filtered Attack type distribution:
# Label
# DoS Hulk                    172849
# DDoS                        128016
# PortScan                     90819
# DoS GoldenEye                10286
# FTP-Patator                   5933
# DoS slowloris                 5385
# DoS Slowhttptest              5228
# SSH-Patator                   3219
# Bot                           1953
# Web Attack - Brute Force      1470
# Web Attack - XSS               652
# Name: count, dtype: int64

# %% [markdown]
# #### 4.2. Under Sampling

# %%
attack_counts = y_attack.value_counts()
sampling_strategy = {}

for label, count in attack_counts.items():
    if count > 3000:
        sampling_strategy[label] = 3000
    else:
        sampling_strategy[label] = count

rus = RandomUnderSampler(sampling_strategy=sampling_strategy, random_state=42)
X_attack_balanced, y_attack_balanced = rus.fit_resample(X_attack, y_attack)

print(f"\nX_attack_balanced shape: {X_attack_balanced.shape}")
print(f"y_attack_balanced shape: {y_attack_balanced.shape}")
print("\nBalanced attack type distribution:")
print(pd.Series(y_attack_balanced).value_counts())
# Out:
# X_attack_balanced shape: (28075, 20)
# y_attack_balanced shape: (28075,)
#
# Balanced attack type distribution:
# Label
# DDoS                        3000
# DoS GoldenEye               3000
# DoS Hulk                    3000
# PortScan                    3000
# DoS Slowhttptest            3000
# DoS slowloris               3000
# FTP-Patator                 3000
# SSH-Patator                 3000
# Bot                         1953
# Web Attack - Brute Force    1470
# Web Attack - XSS             652
# Name: count, dtype: int64

# %% [markdown]
# #### 4.3. Train Test Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_attack_balanced, y_attack_balanced, 
    test_size=0.2, random_state=42, stratify=y_attack_balanced
)

# %% [markdown]
# #### 4.4. SMOTE for Train Class Balancing

# %%
smote_target_counts = {label: 2400 for label in y_train.unique()}

smote = SMOTE(sampling_strategy=smote_target_counts, random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print(f"\nX_train_resampled shape: {X_train_resampled.shape}")
print(f"y_train_resampled shape: {y_train_resampled.shape}")
# Out:
# X_train_resampled shape: (26400, 20)
# y_train_resampled shape: (26400,)

# %% [markdown]
# #### 4.5. Scaling

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)
print(f"\nX_train_scaled shape: {X_train.shape}, X_test_scaled shape: {X_test.shape}")
# Out:
# X_train_scaled shape: (22460, 20), X_test_scaled shape: (5615, 20)

# %%
print("\nTrain set class distribution:")
print(pd.Series(y_train_resampled).value_counts())

print("\nTest set class distribution:")
print(pd.Series(y_test).value_counts())
# Out:
# Train set class distribution:
# Label
# DDoS                        2400
# PortScan                    2400
# DoS slowloris               2400
# DoS Hulk                    2400
# FTP-Patator                 2400
# SSH-Patator                 2400
# DoS Slowhttptest            2400
# DoS GoldenEye               2400
# Web Attack - Brute Force    2400
# Web Attack - XSS            2400
# Bot                         2400
# Name: count, dtype: int64
#
# Test set class distribution:
# Label
# DoS slowloris               600
# DoS Hulk                    600
# DoS GoldenEye               600
# DoS Slowhttptest            600
# DDoS                        600
# PortScan                    600
# SSH-Patator                 600
# FTP-Patator                 600
# Bot                         391
# Web Attack - Brute Force    294
# Web Attack - XSS            130
# Name: count, dtype: int64

# %% [markdown]
# #### 4.6. Visualization

# %%
# --- Görselleştirme ---
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(x=y_train_resampled, ax=axes[0], hue=y_train_resampled, palette='Set2')
axes[0].set_title("Train Set Class Distribution (After SMOTE)")
axes[0].set_xlabel("Class")
axes[0].set_ylabel("Count")
axes[0].tick_params(axis='x', rotation=45)

sns.countplot(x=y_test, ax=axes[1], hue=y_test, palette='Set1')
axes[1].set_title("Test Set Class Distribution")
axes[1].set_xlabel("Class")
axes[1].set_ylabel("Count")
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.6. Define the Models

# %%
models = [
    ('Random Forest', RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)),
    ('SVM', SVC(C=0.5, random_state=42, max_iter=10000)),
    ('Logistic Regression', LogisticRegression(C=0.5, max_iter=10000)),
    ('KNN', KNeighborsClassifier(n_neighbors=5, algorithm='auto')),
    ('Decision Tree', DecisionTreeClassifier(random_state=42, max_depth=10, min_samples_split=5)),
    ('AdaBoostClassifier',AdaBoostClassifier(n_estimators=100, random_state=42))
]

# %% [markdown]
# #### 4.7. Model Evaluation

# %%
def evaluate_models(models, X_train, y_train, X_test, y_test, cv_splits=5, save_dir='multiclass_log'):
    results = {}
    os.makedirs(save_dir, exist_ok=True)

    best_model_name = None
    best_model_score = 0
    best_model_instance = None

    for name, model in models:
        print(f"Evaluating {name}...")

        start_time = time.time()

        # Cross-validation for different metrics
        cv_results = cross_validate(model, X_train, y_train, cv=cv_splits,
                                    scoring=['accuracy', 'f1_weighted', 'precision_weighted', 'recall_weighted'],
                                    return_train_score=False)

        accuracy = cv_results['test_accuracy'].mean()
        f1 = cv_results['test_f1_weighted'].mean()
        precision = cv_results['test_precision_weighted'].mean()
        recall = cv_results['test_recall_weighted'].mean()

        end_time = time.time()
        elapsed_time = end_time - start_time

        results[name] = {
            'accuracy': accuracy,
            'f1': f1,
            'precision': precision,
            'recall': recall,
            'cross_val_time_sec': elapsed_time
        }

        # Save the best model based on F1-score
        if f1 > best_model_score:
            best_model_score = f1
            best_model_name = name
            best_model_instance = model

    # Convert results to DataFrame
    results_df = pd.DataFrame(results).T
    print("\nModel Comparison (Cross-Validation Results):")
    print(results_df)

    # Save results to CSV
    log_path = os.path.join(save_dir, 'model_results_log.csv')
    results_df.to_csv(log_path, index=True)
    print(f"\nResults saved to {log_path}")

    # Plotting the scores (accuracy, f1, precision, recall) - First Graph
    score_metrics = ['accuracy', 'f1', 'precision', 'recall']
    results_df[score_metrics].plot(kind='barh', figsize=(10, 6), cmap='viridis')
    plt.title("Model Evaluation Scores Comparison")
    plt.xlabel("Score")
    plt.ylabel("Models")
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.show()

    # Plotting the cross-validation time - Second Graph
    results_df['cross_val_time_sec'].plot(kind='barh', figsize=(8, 5), color='salmon')
    plt.title("Model Cross-Validation Time Comparison")
    plt.xlabel("Time (seconds)")
    plt.ylabel("Models")
    plt.tight_layout()
    plt.show()

    # Save the best model and generate classification report
    if best_model_instance is not None:
        best_model_instance.fit(X_train, y_train)
        model_path = os.path.join(save_dir, f'best_model_{best_model_name.replace(" ", "_")}.pkl')
        joblib.dump(best_model_instance, model_path)
        print(f"Best model '{best_model_name}' saved to {model_path}")

        # Predict on test set and print classification report
        y_pred = best_model_instance.predict(X_test)
        print("\nClassification Report for Best Model on Test Set:")
        print(classification_report(y_test, y_pred, digits=4))
        print("\nConfusion Matrix:")
        print(confusion_matrix(y_test, y_pred))
        

# Call the function
#evaluate_models(models, X_train_scaled, y_train_resampled, X_test_scaled, y_test)
evaluate_models(models, X_train_resampled, y_train_resampled, X_test, y_test)
# Out:
# Evaluating Random Forest...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 86
#      81         print(confusion_matrix(y_test, y_pred))
#      84 # Call the function
#      85 #evaluate_models(models, X_train_scaled, y_train_resampled, X_test_scaled, y_test)
# ---> 86 evaluate_models(models, X_train_resampled, y_train_resampled, X_test, y_test)
#
# Cell In[40], line 15, in evaluate_models(models, X_train, y_train, X_test, y_test, cv_splits, save_dir)
#      12 start_time = time.time()
#      14 # Cross-validation for different metrics
# ---> 15 cv_results = cross_validate(model, X_train, y_train, cv=cv_splits,
#      16                             scoring=['accuracy', 'f1_weighted', 'precision_weighted', 'recall_weighted'],
#      17                             return_train_score=False)
#      19 accuracy = cv_results['test_accuracy'].mean()
#      20 f1 = cv_results['test_f1_weighted'].mean()
#
# NameError: name 'cross_validate' is not defined
